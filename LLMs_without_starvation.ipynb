# %%
from model_manager import ModelType
from local_llm import LocalLLM

# %%
llm_tinyllama = LocalLLM.get_instance(
       model_type=ModelType.TINYLLAMA,
       device="cpu",
       max_new_tokens=32,  # or 16
       temperature=0.0)

llm_lightgpt = LocalLLM.get_instance(
       model_type=ModelType.LIGHTGPT,
       device="cpu",
       max_new_tokens=32,  # or 16
       temperature=0.0)

llm_phi = LocalLLM.get_instance(
       model_type=ModelType.PHI,
       device="cpu",
       max_new_tokens=32,  # or 16
       temperature=0.0)

llm_llama = LocalLLM.get_instance(
       model_type=ModelType.LLAMA,
       device="cpu",
       max_new_tokens=8,  # or 16
       temperature=0.0)

llm_mistral = LocalLLM.get_instance(
       model_type=ModelType.MISTRAL,
       device="cpu",
       max_new_tokens=32,  # or 16
       temperature=0.0)

llm_falcon = LocalLLM.get_instance(
       model_type=ModelType.FALCON,
       device="cpu",
       max_new_tokens=32,  # or 16
       temperature=0.0)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[4], line 8
#       1 llm_tinyllama = LocalLLM.get_instance(
#       2        model_type=ModelType.TINYLLAMA,
#       3        device="cpu",
#       4        max_new_tokens=32,  # or 16
#       5        temperature=0.0)
#       7 llm_lightgpt = LocalLLM.get_instance(
# ----> 8        model_type=ModelType.LIGHTGPT,
#       9        device="cpu",
#      10        max_new_tokens=32,  # or 16
#      11        temperature=0.0)
#      13 llm_phi = LocalLLM.get_instance(
#      14        model_type=ModelType.PHI,
#      15        device="cpu",
#      16        max_new_tokens=32,  # or 16
#      17        temperature=0.0)
#      19 llm_llama = LocalLLM.get_instance(
#      20        model_type=ModelType.LLAMA,
#      21        device="cpu",
#      22        max_new_tokens=8,  # or 16
#      23        temperature=0.0)
#
# AttributeError: type object 'ModelType' has no attribute 'LIGHTGPT'

# %%
  # Example 1: Minimal prompt
# prompt = "Choose one: GREEN_NORTH_SOUTH 20 or GREEN_EAST_WEST 20\nState: N=4, E=4, S=4, W=4\nAnswer:"

# Q&A format
prompt_qa= (
    "Q: N=4, E=4, S=4, W=4. Which phase? A: GREEN_NORTH_SOUTH 20\n"
    "Q: N=5, E=6, S=5, W=6. Which phase? A: GREEN_EAST_WEST 20\n"
    "Q: N=2, E=10, S=2, W=1. Which phase? A: GREEN_EAST_WEST 20\n"
    "Q: N=8, E=7, S=8, W=7. Which phase? A: GREEN_NORTH_SOUTH 20\n"
    "Q: N=5, E=5, S=5, W=5. Which phase? A: GREEN_EAST_WEST 20\n"
    "Q: N=3, E=3, S=3, W=3. Which phase? A: GREEN_NORTH_SOUTH 20\n"
    "Q: N=6, E=2, S=6, W=2. Which phase? A: GREEN_NORTH_SOUTH 20\n"
    "Q: N=2, E=7, S=2, W=7. Which phase? A: GREEN_EAST_WEST 20\n"
    "Q: N=4, E=4, S=4, W=4. Which phase? A:"
)


# Chat format
prompt_chat = (
    "User: N=4, E=4, S=4, W=4\nAssistant: GREEN_NORTH_SOUTH 20\n"
    "User: N=5, E=6, S=5, W=6\nAssistant: GREEN_EAST_WEST 20\n"
    "User: N=2, E=10, S=2, W=1\nAssistant: GREEN_EAST_WEST 20\n"
    "User: N=8, E=7, S=8, W=7\nAssistant: GREEN_NORTH_SOUTH 20\n"
    "User: N=5, E=5, S=5, W=5\nAssistant: GREEN_EAST_WEST 20\n"
    "User: N=3, E=3, S=3, W=3\nAssistant: GREEN_NORTH_SOUTH 20\n"
    "User: N=6, E=2, S=6, W=2\nAssistant: GREEN_NORTH_SOUTH 20\n"
    "User: N=2, E=7, S=2, W=7\nAssistant: GREEN_EAST_WEST 20\n"
    "User: N=4, E=4, S=4, W=4\nAssistant:"
)

# Direct format
prompt_direct = (
    "State: N=4, E=4, S=4, W=4 -> GREEN_NORTH_SOUTH 20\n"
    "State: N=5, E=6, S=5, W=6 -> GREEN_EAST_WEST 20\n"
    "State: N=2, E=10, S=2, W=1 -> GREEN_EAST_WEST 20\n"
    "State: N=8, E=7, S=8, W=7 -> GREEN_NORTH_SOUTH 20\n"
    "State: N=5, E=5, S=5, W=5 -> GREEN_EAST_WEST 20\n"
    "State: N=3, E=3, S=3, W=3 -> GREEN_NORTH_SOUTH 20\n"
    "State: N=6, E=2, S=6, W=2 -> GREEN_NORTH_SOUTH 20\n"
    "State: N=2, E=7, S=2, W=7 -> GREEN_EAST_WEST 20\n"
    "State: N=4, E=4, S=4, W=4 ->"
)

# %%
print("Loaded model:", llm_phi.model_type, llm_phi.model_config.model_id)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 print("Loaded model:", llm_phi.model_type, llm_phi.model_config.model_id)
#
# AttributeError: 'LocalLLM' object has no attribute 'model_type'

# %%
print("Prompt:\n", prompt_qa)
print("LLM Output:\n", llm_phi.query(prompt_qa, ""))
# Out:
# Prompt:
#  Q: N=4, E=4, S=4, W=4. Which phase? A: GREEN_NORTH_SOUTH 20
# Q: N=5, E=6, S=5, W=6. Which phase? A: GREEN_EAST_WEST 20
# Q: N=2, E=10, S=2, W=1. Which phase? A: GREEN_EAST_WEST 20
# Q: N=8, E=7, S=8, W=7. Which phase? A: GREEN_NORTH_SOUTH 20
# Q: N=5, E=5, S=5, W=5. Which phase? A: GREEN_EAST_WEST 20
# Q: N=3, E=3, S=3, W=3. Which phase? A: GREEN_NORTH_SOUTH 20
# Q: N=6, E=2, S=6, W=2. Which phase? A: GREEN_NORTH_SOUTH 20
# Q: N=2, E=7, S=2, W=7. Which phase? A: GREEN_EAST_WEST 20
# Q: N=4, E=4, S=4, W=4. Which phase? A:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[5], line 2
#       1 print("Prompt:\n", prompt_qa)
# ----> 2 print("LLM Output:\n", llm_phi.query(prompt_qa, ""))
#
# File ~/Desktop/my_projects/zs_cot_traffic_control/local_llm.py:108, in LocalLLM.query(self, system_msg, user_msg)
#     103 def query(self, system_msg: str, user_msg: str) -> str:
#     104     """
#     105     Send (system_msg + user_msg) as a prompt to the model and
#     106     return the generated response.
#     107     """
# --> 108     prompt = self._build_prompt(system_msg, user_msg)
#     110     # Tokenize input
#     111     inputs = self.tokenizer(prompt, return_tensors="pt")
#
# File ~/Desktop/my_projects/zs_cot_traffic_control/local_llm.py:101, in LocalLLM._build_prompt(self, system_msg, user_msg)
#      97 def _build_prompt(self, system_msg: str, user_msg: str) -> str:
#      98     """
#      99     Build prompt using the model's specific format.
#     100     """
# --> 101     return format_prompt(self.model_type, system_msg, user_msg)
#
# AttributeError: 'LocalLLM' object has no attribute 'model_type'

# %%
print("Prompt:\n", prompt_chat)
print("LLM Output:\n", llm_lightgpt.query(prompt_chat, ""))
# Out:
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Prompt:
#  User: N=4, E=4, S=4, W=4
# Assistant: GREEN_NORTH_SOUTH 20
# User: N=5, E=6, S=5, W=6
# Assistant: GREEN_EAST_WEST 20
# User: N=2, E=10, S=2, W=1
# Assistant: GREEN_EAST_WEST 20
# User: N=8, E=7, S=8, W=7
# Assistant: GREEN_NORTH_SOUTH 20
# User: N=5, E=5, S=5, W=5
# Assistant: GREEN_EAST_WEST 20
# User: N=3, E=3, S=3, W=3
# Assistant: GREEN_NORTH_SOUTH 20
# User: N=6, E=2, S=6, W=2
# Assistant: GREEN_NORTH_SOUTH 20
# User: N=2, E=7, S=2, W=7
# Assistant: GREEN_EAST_WEST 20
# User: N=4, E=4, S=4, W=4
# Assistant:
# LLM Output:
#  User: N=4, E=

# %%
print("Prompt:\n", prompt_direct)
print("LLM Output:\n", llm_lightgpt.query(prompt_direct, ""))
# Out:
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Prompt:
#  State: N=4, E=4, S=4, W=4 -> GREEN_NORTH_SOUTH 20
# State: N=5, E=6, S=5, W=6 -> GREEN_EAST_WEST 20
# State: N=2, E=10, S=2, W=1 -> GREEN_EAST_WEST 20
# State: N=8, E=7, S=8, W=7 -> GREEN_NORTH_SOUTH 20
# State: N=5, E=5, S=5, W=5 -> GREEN_EAST_WEST 20
# State: N=3, E=3, S=3, W=3 -> GREEN_NORTH_SOUTH 20
# State: N=6, E=2, S=6, W=2 -> GREEN_NORTH_SOUTH 20
# State: N=2, E=7, S=2, W=7 -> GREEN_EAST_WEST 20
# State: N=4, E=4, S=4, W=4 ->
# LLM Output:
#  State: N=4,
